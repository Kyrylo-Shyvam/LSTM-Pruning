# %%
# !git clone -b change-init https://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@github.com/Kyrylo-Shyvam/LSTM-Pruning.git
# Out:
# Cloning into 'LSTM-Pruning'...
# remote: Enumerating objects: 327, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 327 (delta 73), reused 97 (delta 60), pack-reused 214
# Receiving objects: 100% (327/327), 483.96 MiB | 29.84 MiB/s, done.
# Resolving deltas: 100% (162/162), done.
# Updating files: 100% (49/49), done.

# %%
# !ls
# %cd ./LSTM-Pruning/code
# !ls
# !ls ./work_dir/
import wandb
import lstmModel
# Out:
# LSTM-Pruning  __notebook__.ipynb
# /kaggle/working/LSTM-Pruning/code
# README.md    batch.sh  iwslt2014_ende.zip  lstmModel.py     scripts   vocab.py
# __pycache__  data      lstmModel.ipynb	   multi-bleu.perl  utils.py  work_dir
# README.md   model0.bin	model2.bin  model4.bin
# decode.txt  model1.bin	model3.bin
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
wandb.login(key="14dded5f079435f64fb5e2f0278662dda5605f9e")
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
! ./scripts/retrain.sh model3.bin 'class-blind' 0.5 0.001
wandb.init(project="pruning_with_retraining")
wandb.config.pruningType = 'class-blind'
wandb.config.percentage = 0.5
wandb.config.model_name = 'model3'
wandb.config.lr = 0.001
bleu = lstmModel.decode({
                '--beam-size': '5',
                '--cuda': 'True',
                '--max-decoding-time-step': '100',
                'MODEL_PATH': './work_dir/model.bin.final',
                'TEST_SOURCE_FILE': './data/test.de-en.de',
                'TEST_TARGET_FILE': './data/test.de-en.en',
                'OUTPUT_FILE': './work_dir/decode.txt'
            })
wandb.log({"bleu": bleu})
wandb.finish()
# Out:
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# wandb: Currently logged in as: vanshikadhingra1030. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231105_122646-j9ri9eby
# wandb: Run `wandb offline` to turn off syncing.
# ...

# %%
! ./scripts/retrain.sh model3.bin 'class-blind' 0.6 0.001
wandb.init(project="pruning_with_retraining")
wandb.config.pruningType = 'class-blind'
wandb.config.percentage = 0.6
wandb.config.model_name = 'model3'
wandb.config.lr = 0.001
bleu = lstmModel.decode({
                '--beam-size': '5',
                '--cuda': 'True',
                '--max-decoding-time-step': '100',
                'MODEL_PATH': './work_dir/model.bin.final',
                'TEST_SOURCE_FILE': './data/test.de-en.de',
                'TEST_TARGET_FILE': './data/test.de-en.en',
                'OUTPUT_FILE': './work_dir/decode.txt'
            })
wandb.log({"bleu": bleu})
wandb.finish()
# Out:
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# wandb: Currently logged in as: vanshikadhingra1030. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231105_130256-zylt5dmk
# wandb: Run `wandb offline` to turn off syncing.
# ...

# %%
! ./scripts/retrain.sh model3.bin 'class-blind' 0.7 0.001
wandb.init(project="pruning_with_retraining")
wandb.config.pruningType = 'class-blind'
wandb.config.percentage = 0.7
wandb.config.model_name = 'model3'
wandb.config.lr = 0.001
bleu = lstmModel.decode({
                '--beam-size': '5',
                '--cuda': 'True',
                '--max-decoding-time-step': '100',
                'MODEL_PATH': './work_dir/model.bin.final',
                'TEST_SOURCE_FILE': './data/test.de-en.de',
                'TEST_TARGET_FILE': './data/test.de-en.en',
                'OUTPUT_FILE': './work_dir/decode.txt'
            })
wandb.log({"bleu": bleu})
wandb.finish()
# Out:
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# wandb: Currently logged in as: vanshikadhingra1030. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231105_133849-4go5hpl2
# wandb: Run `wandb offline` to turn off syncing.
# ...

# %%
! ./scripts/retrain.sh model3.bin 'class-blind' 0.8 0.001
wandb.init(project="pruning_with_retraining")
wandb.config.pruningType = 'class-blind'
wandb.config.percentage = 0.8
wandb.config.model_name = 'model3'
wandb.config.lr = 0.001
bleu = lstmModel.decode({
                '--beam-size': '5',
                '--cuda': 'True',
                '--max-decoding-time-step': '100',
                'MODEL_PATH': './work_dir/model.bin.final',
                'TEST_SOURCE_FILE': './data/test.de-en.de',
                'TEST_TARGET_FILE': './data/test.de-en.en',
                'OUTPUT_FILE': './work_dir/decode.txt'
            })
wandb.log({"bleu": bleu})
wandb.finish()
# Out:
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# wandb: Currently logged in as: vanshikadhingra1030. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231105_141438-7xs3mzbi
# wandb: Run `wandb offline` to turn off syncing.
# ...

# %%
! ./scripts/retrain.sh model3.bin 'class-blind' 0.9 0.001
wandb.init(project="pruning_with_retraining")
wandb.config.pruningType = 'class-blind'
wandb.config.percentage = 0.9
wandb.config.model_name = 'model3'
wandb.config.lr = 0.001
bleu = lstmModel.decode({
                '--beam-size': '5',
                '--cuda': 'True',
                '--max-decoding-time-step': '100',
                'MODEL_PATH': './work_dir/model.bin.final',
                'TEST_SOURCE_FILE': './data/test.de-en.de',
                'TEST_TARGET_FILE': './data/test.de-en.en',
                'OUTPUT_FILE': './work_dir/decode.txt'
            })
wandb.log({"bleu": bleu})
wandb.finish()
# Out:
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# wandb: Currently logged in as: vanshikadhingra1030. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231105_145055-7wwanvwy
# wandb: Run `wandb offline` to turn off syncing.
# ...
