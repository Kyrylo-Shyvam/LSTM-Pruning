# %%
import torch
import torchvision
from torch import nn
import torch.nn.utils.prune as prune
import torch.nn.functional as F
import wandb

# %%
# !git clone -b snip https://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@github.com/Kyrylo-Shyvam/LSTM-Pruning.git --depth 1 -b snip
# Out:
# Cloning into 'LSTM-Pruning'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (200/200), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 200 (delta 59), reused 178 (delta 51), pack-reused 0
# Receiving objects: 100% (200/200), 459.38 MiB | 23.09 MiB/s, done.
# Resolving deltas: 100% (59/59), done.
# Updating files: 100% (176/176), done.

# %%
# %cd ./LSTM-Pruning/code
# Out:
# /kaggle/working/LSTM-Pruning/code

# %%
import lstmModel
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
wandb.login(key="14dded5f079435f64fb5e2f0278662dda5605f9e")
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !ls ./scripts/snip-prune.sh
# Out:
# ./scripts/snip-prune.sh

# %%
! chmod +x ./scripts/snip-prune.sh

# %%
def class_uniform_sub(module):
    layers=[]
    weights=[]
    for weight_name,weights_matrix in module.named_parameters():
        weights.append(weights_matrix.flatten())
        layers.append([module,weight_name])
    a = 0
    if len(layers) > 0:
        weights=torch.cat(weights)
    return weights

# %%
def calculate_percentage_of_zeros(weights):
    total_elements = weights.numel()
    zero_elements = torch.sum(weights == 0).item()
    percentage_zeros = (zero_elements / total_elements) * 100
    return percentage_zeros

# %%
percentages=[0.50,0.60,0.70,0.80]

# %%
for percentage in percentages:
    # !./scripts/prune.sh 'model0.bin' 'class-blind' {percentage}
    model=lstmModel.NMT.load('./work_dir/model0.bin.pruned')
    for i,j in model.named_children():
        if i !='dropout' and i!='label_smoothing_loss':
            weights=class_uniform_sub(j)
            wandb.init(project="snip-percentage-pruned-per-class")
            wandb.config.percentage = {percentage}
            wandb.config.lr=0.0025
            wandb.config.epoch = 25
            wandb.config.pruning_type='class-blind'
            wandb.config.pretrainingBatchSize=2000
            wandb.config.classN=i
            wandb.log({"percentage-pruned":calculate_percentage_of_zeros(weights)})
            wandb.finish()
# Out:
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# save model parameters to [work_dir/model0.bin.pruned]
# lastr
# wandb: Currently logged in as: vanshikadhingra1030 (optimalbraindamage). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_225412-fpvtzzq8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run pretty-wildflower-72
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/fpvtzzq8
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 49.13661
# wandb:
# wandb: 🚀 View run pretty-wildflower-72 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/fpvtzzq8
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_225412-fpvtzzq8/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_225505-ekkq51in
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vibrant-jazz-74
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/ekkq51in
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 49.70272
# wandb:
# wandb: 🚀 View run vibrant-jazz-74 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/ekkq51in
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_225505-ekkq51in/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_225557-9karm9me
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run valiant-sunset-75
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/9karm9me
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 43.33192
# wandb:
# wandb: 🚀 View run valiant-sunset-75 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/9karm9me
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_225557-9karm9me/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_225650-hwwm14q8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run still-lion-76
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/hwwm14q8
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 48.84412
# wandb:
# wandb: 🚀 View run still-lion-76 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/hwwm14q8
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_225650-hwwm14q8/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_225742-h15oic5y
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run breezy-water-77
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/h15oic5y
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 48.56724
# wandb:
# wandb: 🚀 View run breezy-water-77 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/h15oic5y
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_225742-h15oic5y/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_225834-1h424eap
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run devoted-grass-79
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/1h424eap
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 52.82914
# wandb:
# wandb: 🚀 View run devoted-grass-79 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/1h424eap
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_225834-1h424eap/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_225926-wanti3b3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run comic-butterfly-81
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/wanti3b3
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 57.17545
# wandb:
# wandb: 🚀 View run comic-butterfly-81 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/wanti3b3
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_225926-wanti3b3/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230019-jtx3fgzt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run graceful-resonance-83
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/jtx3fgzt
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 48.17963
# wandb:
# wandb: 🚀 View run graceful-resonance-83 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/jtx3fgzt
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230019-jtx3fgzt/logs
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# save model parameters to [work_dir/model0.bin.pruned]
# lastr
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230122-xpi28aca
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run breezy-sun-85
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/xpi28aca
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 59.20473
# wandb:
# wandb: 🚀 View run breezy-sun-85 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/xpi28aca
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230122-xpi28aca/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230214-es65uroo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sage-deluge-87
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/es65uroo
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 59.76665
# wandb:
# wandb: 🚀 View run sage-deluge-87 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/es65uroo
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230214-es65uroo/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230307-gsy59e7a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sandy-rain-89
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/gsy59e7a
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 52.44084
# wandb:
# wandb: 🚀 View run sandy-rain-89 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/gsy59e7a
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230307-gsy59e7a/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230401-3ng3ro2m
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run elated-paper-91
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/3ng3ro2m
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 58.51837
# wandb:
# wandb: 🚀 View run elated-paper-91 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/3ng3ro2m
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230401-3ng3ro2m/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230454-c6t5v5bh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run graceful-haze-93
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/c6t5v5bh
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 57.54908
# wandb:
# wandb: 🚀 View run graceful-haze-93 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/c6t5v5bh
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230454-c6t5v5bh/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230547-78etxtey
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run whole-wildflower-94
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/78etxtey
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 62.98662
# wandb:
# wandb: 🚀 View run whole-wildflower-94 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/78etxtey
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230547-78etxtey/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230639-nrbzhmp6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run clean-pine-95
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/nrbzhmp6
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 67.48886
# wandb:
# wandb: 🚀 View run clean-pine-95 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/nrbzhmp6
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230639-nrbzhmp6/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230731-p49b88yx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mild-frost-97
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/p49b88yx
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 57.62278
# wandb:
# wandb: 🚀 View run mild-frost-97 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/p49b88yx
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230731-p49b88yx/logs
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# save model parameters to [work_dir/model0.bin.pruned]
# lastr
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230833-jcujw63x
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run driven-field-99
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/jcujw63x
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 69.36626
# wandb:
# wandb: 🚀 View run driven-field-99 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/jcujw63x
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230833-jcujw63x/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_230924-6u3kwtoa
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run azure-dew-101
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/6u3kwtoa
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 69.88686
# wandb:
# wandb: 🚀 View run azure-dew-101 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/6u3kwtoa
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_230924-6u3kwtoa/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231017-il3jzhtr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sparkling-cloud-103
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/il3jzhtr
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 61.83066
# wandb:
# wandb: 🚀 View run sparkling-cloud-103 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/il3jzhtr
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231017-il3jzhtr/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231110-w4g8dxli
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run graceful-galaxy-105
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/w4g8dxli
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 68.14084
# wandb:
# wandb: 🚀 View run graceful-galaxy-105 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/w4g8dxli
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231110-w4g8dxli/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231202-lozsipuo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run valiant-cloud-107
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/lozsipuo
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 66.31684
# wandb:
# wandb: 🚀 View run valiant-cloud-107 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/lozsipuo
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231202-lozsipuo/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231255-65riettb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run different-blaze-109
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/65riettb
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 72.95829
# wandb:
# wandb: 🚀 View run different-blaze-109 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/65riettb
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231255-65riettb/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231346-htfudnmg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vivid-frog-111
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/htfudnmg
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 77.02713
# wandb:
# wandb: 🚀 View run vivid-frog-111 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/htfudnmg
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231346-htfudnmg/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231438-u274grjt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run lunar-field-112
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/u274grjt
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 66.92912
# wandb:
# wandb: 🚀 View run lunar-field-112 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/u274grjt
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231438-u274grjt/logs
# save results to work_dir
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# save model parameters to [work_dir/model0.bin.pruned]
# lastr
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231540-lenexm4y
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run noble-salad-113
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/lenexm4y
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 79.66212
# wandb:
# wandb: 🚀 View run noble-salad-113 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/lenexm4y
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231540-lenexm4y/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231632-xh4bmki6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run charmed-breeze-114
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/xh4bmki6
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 80.05156
# wandb:
# wandb: 🚀 View run charmed-breeze-114 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/xh4bmki6
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231632-xh4bmki6/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231724-x61zvkxs
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run visionary-glade-115
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/x61zvkxs
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 71.77383
# wandb:
# wandb: 🚀 View run visionary-glade-115 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/x61zvkxs
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231724-x61zvkxs/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231816-3iedoqc7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run treasured-totem-116
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/3iedoqc7
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 77.83032
# wandb:
# wandb: 🚀 View run treasured-totem-116 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/3iedoqc7
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231816-3iedoqc7/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_231909-tqvycg82
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run rare-surf-117
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/tqvycg82
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 75.07039
# wandb:
# wandb: 🚀 View run rare-surf-117 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/tqvycg82
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_231909-tqvycg82/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_232000-5mjx2zzp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run whole-frog-118
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/5mjx2zzp
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 82.61585
# wandb:
# wandb: 🚀 View run whole-frog-118 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/5mjx2zzp
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_232000-5mjx2zzp/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_232053-ir0wwzvr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eternal-snowball-119
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/ir0wwzvr
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 85.7666
# wandb:
# wandb: 🚀 View run eternal-snowball-119 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/ir0wwzvr
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_232053-ir0wwzvr/logs
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/LSTM-Pruning/code/wandb/run-20231126_232145-s7a2j565
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run happy-dew-120
# wandb: ⭐️ View project at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class
# wandb: 🚀 View run at https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/s7a2j565
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb:
# wandb:
# wandb: Run history:
# wandb: percentage-pruned ▁
# wandb:
# wandb: Run summary:
# wandb: percentage-pruned 76.22986
# wandb:
# wandb: 🚀 View run happy-dew-120 at: https://wandb.ai/optimalbraindamage/snip-percentage-pruned-per-class/runs/s7a2j565
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231126_232145-s7a2j565/logs
